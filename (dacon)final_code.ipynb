# %%
import pandas as pd
from glob import glob
from tqdm import tqdm
import warnings

warnings.filterwarnings(action='ignore') 
know_train = [pd.read_csv(path) for path in sorted(glob('/Users/home/Desktop/know_data/train/*.csv'))]
know_test = [pd.read_csv(path) for path in sorted(glob('/Users/home/Desktop/know_data/test/*.csv'))]

# %%
know_train[3].select_dtypes(["object"])
# Out:
#         bq4_1a   bq4_1b bq4_1c         bq5_2  \
# 0     보건교사 자격증  간호사 자격증     없음             0
# 1          법무사       없음     없음         현장 업무
# 2            0        0      0             0
# 3     보건교사 자격증       없음     없음  기초보건교육, 인성교육
# 4         건축기사       없음     없음             0
# ...        ...      ...    ...           ...
# 8117         0        0      0             0
# 8118         0        0      0             0
# 8119     보험계리사       없음     없음             0
# 8120   화학분석기능사       없음     없음             0
# 8121         0        0      0             0
#
#                                                 bq20_1  bq26_1
# 0                   일정하게 인원이 정해져 있으므로 일자리 변화는 없을 것 같아서     간호학
# 1                                                경기 침체    기계공학
# 2                                       전체적으로 경기 악화 때문      기계
# 3     사람의 상태를 소통하며 확인해서 그에 맞는 각가의 처방을 내려줘야 하는 일이라 대체불가     보건학
# 4                          건설경기가 아직은 침체에서 일어나기 힘들 것 같다  건축설비공학
# ...

# %%
from sklearn.preprocessing import LabelEncoder
years = ['2017', '2018', '2019', '2020']

year_encoder = {}

for year, df in zip(years, know_train):
    print(year)
    encoders = {}
    
    for col in df.columns:
        if col == 'ID':
            continue
        
        try:
            df[col] = df[col].map(int)
        except:
            encoder = LabelEncoder()
            df[col] = df[col].map(str)
            df[col] = encoder.fit_transform(df[col])
            encoders[col] = encoder
            
            
    year_encoder[year] = encoders
# Out:
# 2017
# 2018
# 2019
# 2020

# %%
train_data = {}
for year, df in zip(years, know_train):
    train_data[year] = {'X': df.iloc[:, 1:-1], # ID제외
                        'y': df.iloc[:, -1]}

# %%
from sklearn.model_selection import train_test_split
x={}
y={}
for year in years:
    x[year]=train_data[year]['X'].iloc[:, 1:]
    y[year]=train_data[year]['y']
    x_train, x_valid, y_train, y_valid = train_test_split(x[year],y[year])

# %%
x_train[2]
# Out:
# array([-1.49543356e-01,  6.47003655e-01,  6.49679639e-01, -3.47479222e-02,
#         2.62678990e-01,  4.29468229e-01, -9.52279485e-01,  1.65842977e-01,
#        -5.84936366e-01, -7.14957983e-02,  4.62539857e-02, -2.79317662e-01,
#        -1.26765083e+00, -1.39326629e+00,  5.20704684e-03,  2.33177105e-01,
#        -1.11320774e+00, -5.14849842e-01, -1.51830202e+00, -1.70023631e+00,
#         2.74563239e-01, -4.92740646e-02,  1.30347856e-01,  2.73784002e-01,
#        -2.20244858e+00, -2.52332689e+00, -1.56374305e+00, -1.73000875e+00,
#        -1.58232728e+00, -1.79899718e+00, -8.11202461e-01, -8.04739677e-01,
#        -1.32930389e+00, -1.47658581e+00, -4.18191530e-01,  9.94571664e-02,
#        -1.47074492e+00, -1.66073790e+00,  1.41557938e-04, -2.88804813e-01,
#        -1.71604980e-01,  1.37311495e-01, -1.78239954e+00, -1.99470379e+00,
#        -1.11164958e-02, -3.26163002e-01, -3.15350307e-01,  2.24146173e-01,
# ...

# %%
y_valid
# Out:
# 7568    623002
# 5704    851201
# 7862    561501
# 1832     25101
# 4626    511201
#          ...
# 410     416501
# 2096    521304
# 3859    306502
# 2143    823101
# 7468    416204
# Name: knowcode, Length: 2031, dtype: int64

# %%
y_train
# Out:
# 1750    704001
# 3365    411301
# 3905    832201
# 4441    881201
# 398     250301
#          ...
# 985     250201
# 6483    232101
# 3151    882101
# 4375    140301
# 3137    542001
# Name: knowcode, Length: 6091, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_valid = scaler.transform(x_valid)

# %%
x_valid
# Out:
# array([[-1.90121371, -2.20913438, -2.18905686, ...,  0.11792036,
#         -0.37955844,  1.09681383],
#        [-0.14954336,  0.64700365, -0.29656586, ..., -0.52166372,
#         -0.37955844,  0.78321044],
#        [-1.02537853, -1.06667917,  0.64967964, ...,  2.67625671,
#          2.63464037, -0.47120312],
#        ...,
#        [ 0.72629182,  0.64700365,  0.64967964, ..., -0.52166372,
#         -0.37955844,  0.31280535],
#        [-1.02537853, -1.06667917, -1.24281136, ..., -0.52166372,
#         -0.37955844,  1.09681383],
#        [-1.02537853, -1.06667917, -0.29656586, ...,  0.75750445,
#         -0.37955844, -1.2552116 ]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

dt_models = {}

for year in tqdm(years):
    def ml_fit(model):
        model.fit(x_train, y_train)
        prediction = model.predict(x_valid)
        accuracy = accuracy_score(prediction, y_valid)
        dt_models[year] = model
        print(model)
        print(f'총 {y_valid.shape[0]}명 중 {accuracy * 100:.3f}% 정확도로 직업을 맞춤')
        return dt_models

# 기본 설정으로만 테스트 
model = ml_fit(RandomForestClassifier(n_estimators=300))
model = ml_fit(LogisticRegression(solver='lbfgs'))
model = ml_fit(SVC(gamma='scale'))
model = ml_fit(KNeighborsClassifier())
model = ml_fit(GaussianNB())
model = ml_fit(DecisionTreeClassifier())
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 7891.45it/s]
# RandomForestClassifier(n_estimators=300)
# 총 2031명 중 51.600% 정확도로 직업을 맞춤

# %%
model = ml_fit(RandomForestClassifier(n_estimators=300, criterion="entropy", max_depth=16, random_state=123456))
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=16, n_estimators=300,
#                        random_state=123456)
# 총 2031명 중 48.794% 정확도로 직업을 맞춤

# %%
model
# Out:
# {'2020': RandomForestClassifier(criterion='entropy', max_depth=16, n_estimators=300,
#                         random_state=123456)}

# %%
model = ml_fit(RandomForestClassifier(n_estimators=300, criterion="entropy", max_depth=16, random_state=123456))

# %%
model = ml_fit(RandomForestClassifier(n_estimators=500, criterion="entropy", max_depth=16, random_state=123456))
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=16, n_estimators=500,
#                        random_state=123456)
# 총 3249명 중 46.568% 정확도로 직업을 맞춤

# %%
model = ml_fit(RandomForestClassifier(n_estimators=300, criterion="entropy", max_depth=16, random_state=123456))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

RF_classifier = RandomForestClassifier()

RF_paramgrid = {
    'max_depth' : [16],
    'n_estimators': [300],
    'max_features': ['sqrt'],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'bootstrap': [True],
    'criterion': ['entropy']
    }

k_fold = StratifiedKFold(n_splits=5)
RF_classifiergrid = GridSearchCV(RF_classifier, param_grid = RF_paramgrid, cv=k_fold, scoring="accuracy", n_jobs= -1, verbose=1)

RF_classifiergrid.fit(x_train, y_train)

rf = RF_classifiergrid.best_estimator_
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   57.7s remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   57.8s finished

# %%
print(RF_classifiergrid.best_score_)
print(RF_classifiergrid.best_params_)
print(RF_classifiergrid.best_estimator_)
# Out:
# 0.4986042019421556
# {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# RandomForestClassifier(criterion='entropy', max_depth=16, max_features='sqrt',
#                        n_estimators=300)

# %%
dt_predicts=[]

pred = RF_classifiergrid.predict(x_valid)
dt_predicts.extend(pred)

# %%
dt_predicts
# Out:
# [701701,
#  851201,
#  561501,
#  25101,
#  511201,
#  307601,
#  29501,
#  15101,
#  23401,
#  811501,
#  133201,
#  824101,
#  511302,
#  13601,
#  861101,
#  812102,
#  24404,
#  121106,
#  612101,
#  614001,
#  411202,
#  232901,
#  153203,
#  140101,
#  31501,
#  110102,
#  32302,
#  812301,
#  817101,
#  702601,
#  214501,
#  212201,
#  306701,
#  306903,
#  140201,
#  812201,
#  214501,
#  122101,
#  134302,
#  28203,
#  13501,
#  561201,
#  416202,
#  23301,
#  214101,
#  12201,
#  872301,
#  153103,
#  29901,
#  416105,
#  621301,
#  615701,
#  110103,
#  862301,
#  863201,
#  27101,
#  532201,
#  813201,
#  27101,
#  31301,
#  615203,
#  122201,
#  122101,
#  615401,
#  812101,
#  151201,
#  420201,
#  521201,
#  872101,
#  511501,
#  121104,
#  31401,
#  882101,
#  416302,
#  701501,
#  622304,
#  153106,
#  904201,
#  416601,
#  153104,
#  306901,
#  134201,
#  823301,
#  701201,
#  415504,
#  240101,
#  110101,
#  532201,
#  414503,
#  414102,
#  862201,
#  826101,
# ...

# %%
import pandas as pd

pd.DataFrame(dt_predicts)
# Out:
#            0
# 0     701701
# 1     851201
# 2     561501
# 3      25101
# 4     511201
# ...      ...
# 2026  416501
# 2027  521304
# 2028  301101
# 2029  904101
# 2030  416204
#
# [2031 rows x 1 columns]
